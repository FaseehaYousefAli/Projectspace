# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.iloc[10474: 10494]
# Out:
#                                                     App           Category  \
# 10474                                      Sat-Fi Voice      COMMUNICATION
# 10475                                  Wi-Fi Visualizer              TOOLS
# 10476                             Lennox iComfort Wi-Fi          LIFESTYLE
# 10477                       Sci-Fi Sounds and Ringtones    PERSONALIZATION
# 10478                                     Sci Fi Sounds             FAMILY
# 10479                                Free Wi-fi HotspoT      COMMUNICATION
# 10480                    FJ 4x4 Cruiser Offroad Driving             FAMILY
# 10481                       FJ 4x4 Cruiser Snow Driving             FAMILY
# 10482                      Wallpapers Toyota FJ Cruiser    PERSONALIZATION
# 10483            New Wallpapers Toyota FJ Cruiser Theme    PERSONALIZATION
# 10484                      FJ Final Join , Circles Game               GAME
# ...

# %%
df.sample(10)
# Out:
#                                                      App         Category  \
# 7030                         Elmo Calls by Sesame Street           FAMILY
# 648                                       Iraq love chat           DATING
# 8547                              Fifth Edition DM Tools           FAMILY
# 4655           U Assist - Screen Mirroring & Sharing App     PRODUCTIVITY
# 5241                                  Blackjack aj Poker             GAME
# 514                                   FarmersOnly Dating           DATING
# 730                                  PINKFONG Baby Shark        EDUCATION
# 10338  Theme for Galaxy Note FE Launcher | Live Wallp...  PERSONALIZATION
# 3412                          Dog Licks Screen Wallpaper  PERSONALIZATION
# 9730                                             Lean EQ         BUSINESS
#
#        Rating Reviews  Size    Installs  Type   Price Content Rating  \
# 7030      3.9    6903   25M  1,000,000+  Free       0       Everyone
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df.drop_duplicates(inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
print(f'The number of Rows are "{df.shape[0]}", and the number of columns are "{df.shape[1]}"')
# Out:
# The number of Rows are "10358", and the number of columns are "13"

# %%
print(f'The name of the columns are: {df.columns}')
# Out:
# The name of the columns are: Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df["Type"].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  8893.000000
# mean      4.189542
# std       0.545452
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  8893.000000  1.035700e+04
# mean      4.189542  4.059046e+05
# std       0.545452  2.696778e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.200000e+01
# 50%       4.300000  1.680000e+03
# 75%       4.500000  4.641600e+04
# max      19.000000  7.815831e+07

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1526
# 11M                    188
# 13M                    186
# 12M                    186
# 14M                    182
# 15M                    174
# 17M                    155
# 26M                    145
# 16M                    143
# 19M                    135
# 10M                    133
# 20M                    131
# 25M                    131
# 21M                    130
# 24M                    129
# 18M                    124
# 23M                    109
# 22M                    108
# 29M                     95
# 27M                     94
# 28M                     92
# 30M                     84
# 33M                     78
# 3.3M                    76
# 37M                     72
# 31M                     69
# 35M                     68
# 2.5M                    68
# 2.3M                    68
# 2.9M                    67
# 2.8M                    65
# 3.4M                    64
# 3.7M                    63
# 32M                     62
# ...

# %%
df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Size'] = df['Size'].replace('Varies with device', pd.NA)
def size_to_mb(size):
    if pd.isna(size):
        return None
    size = str(size).strip().upper()
    if 'M' in size:
        return float(size.replace('M', ''))
    elif 'K' in size:
        return float(size.replace('K', '')) / 1024
    return None

df['Size_MB'] = df['Size'].apply(size_to_mb)

# %%
df['Size'] = df['Size'].apply(convert_into_bytes)

# %%
df['Size']
# Out:
# 0         19922944.0
# 1         14680064.0
# 2          9122611.2
# 3         26214400.0
# 4          2936012.8
# 5          5872025.6
# 6         19922944.0
# 7         30408704.0
# 8         34603008.0
# 9          3250585.6
# 10        29360128.0
# 11        12582912.0
# 12        20971520.0
# 13        22020096.0
# 14        38797312.0
# 15         2831155.2
# 16         5767168.0
# 17        17825792.0
# 18        40894464.0
# 19        32505856.0
# 20        14680064.0
# 21        12582912.0
# 22         4404019.2
# 23         7340032.0
# 24        24117248.0
# 25         6291456.0
# 26        26214400.0
# 27         6396313.6
# 28         4823449.6
# 29         4404019.2
# 30         9646899.2
# 31         5452595.2
# 32        11534336.0
# 33        11534336.0
# 34         4404019.2
# 35         9646899.2
# 36        25165824.0
# 37              None
# 38        11534336.0
# 39         9856614.4
# 40        15728640.0
# 41        10485760.0
# 42              None
# ...

# %%
df['Installs'] = df['Installs'].astype(str).str.replace(r'[+,]', '', regex=True)
df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce')

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1.000000e+06    1488
# 1.000000e+07    1132
# 1.000000e+05    1129
# 1.000000e+04    1033
# 1.000000e+03     890
# 1.000000e+02     710
# 5.000000e+06     683
# 5.000000e+05     517
# 5.000000e+04     474
# 5.000000e+03     469
# 1.000000e+01     385
# 1.000000e+08     369
# 5.000000e+02     328
# 5.000000e+07     272
# 5.000000e+01     204
# 5.000000e+00      82
# 1.000000e+00      67
# 5.000000e+08      61
# 1.000000e+09      49
# 0.000000e+00      15
# Name: count, dtype: int64

# %%
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['no', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['Installs_category'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df['Installs_category'].value_counts()
# Out:
# Installs_category
# Low                   2132
# High                  2005
# Very High             1815
# More than moderate    1603
# Moderate              1502
# Top Notch              751
# Very low               534
# no                      15
# Name: count, dtype: int64

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'] = df['Price'].astype(str).str.replace(r'[$]', '', regex=True)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,    nan,   1.2 ,   1.04])

# %%
df['Price'] = df['Price'].astype('float')

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price      Size_MB
# count  8893.000000  1.035700e+04  1.035700e+04  10357.000000  8831.000000
# mean      4.189542  4.059046e+05  1.415776e+07      1.030800    21.287413
# std       0.545452  2.696778e+06  8.023955e+07     16.278625    22.540591
# min       1.000000  0.000000e+00  0.000000e+00      0.000000     0.008301
# 25%       4.000000  3.200000e+01  1.000000e+03      0.000000     4.700000
# 50%       4.300000  1.680000e+03  1.000000e+05      0.000000    13.000000
# 75%       4.500000  4.641600e+04  1.000000e+06      0.000000    29.000000
# max      19.000000  7.815831e+07  1.000000e+09    400.000000   100.000000

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Size_MB              1527
# Size                 1526
# Rating               1465
# Current Ver             8
# Android Ver             3
# Installs                1
# Reviews                 1
# Content Rating          1
# Installs_category       1
# Type                    1
# Price                   1
# App                     0
# Category                0
# Last Updated            0
# Genres                  0
# dtype: int64

# %%
plt.figure(figsize=(10, 3))
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values in each Column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column')

# %%
plt.figure(figsize=(16, 5))
missing_percentage[missing_percentage < 1].plot(kind='bar')
plt.xlabel('Columns') 
plt.ylabel('Percentage') 
plt.title('Percentage of Missing Values in each Column without Rating column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column without Rating column')

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Size_MB', 'Installs_category'],
#       dtype='object')

# %%
numeric_cols = [i for i in df.columns if df[i].dtype != 'object' ]

# %%
numeric_cols.remove("Installs_category")

# %%
numeric_cols
# Out:
# ['Rating', 'Reviews', 'Installs', 'Price', 'Size_MB']

# %%
corr = df[numeric_cols].corr()

# %%
corr
# Out:
#             Rating   Reviews  Installs     Price   Size_MB
# Rating    1.000000  0.068732  0.050886 -0.022355  0.081969
# Reviews   0.068732  1.000000  0.634997 -0.009417  0.237891
# Installs  0.050886  0.634997  1.000000 -0.011147  0.168872
# Price    -0.022355 -0.009417 -0.011147  1.000000 -0.023769
# Size_MB   0.081969  0.237891  0.168872 -0.023769  1.000000

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap=sns.diverging_palette(130, 330, as_cmap=True), annot=True)
plt.show()

# %%
df.dropna(subset=['Current Ver', 'Android Ver', 'Category', 'Type', 'Genres'],
inplace=True)

# %%
print(f"Length of the dataframe after removing null values: {len(df)}")
# Out:
# Length of the dataframe after removing null values: 10346

# %%
df.groupby('Installs_category')['Rating'].describe()
# Out:
#                      count      mean       std  min  25%  50%  75%  max
# Installs_category
# no                     0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Very low              81.0  4.637037  0.845199  1.0  4.8  5.0  5.0  5.0
# Low                 1255.0  4.170040  0.829420  1.0  3.8  4.4  4.8  5.0
# Moderate            1413.0  4.031352  0.605581  1.4  3.8  4.2  4.5  5.0
# More than moderate  1571.0  4.094653  0.504221  1.6  3.9  4.2  4.5  4.9
# High                2000.0  4.207100  0.378591  1.8  4.0  4.3  4.5  4.9
# Very High           1815.0  4.285675  0.301071  2.0  4.1  4.3  4.5  4.9
# Top Notch            751.0  4.372170  0.195374  3.1  4.3  4.4  4.5  4.8

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(1460)

# %%
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# Low                   874
# Very low              452
# Moderate               86
# More than moderate     31
# no                     14
# High                    3
# Very High               0
# Top Notch               0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x='Installs_category', y='Rating', hue='Installs_category', data=df)
plt.text(0, 3.5, 'Null values: 14')
plt.text(1, 3.5, 'Null values: 874')
plt.text(2, 3.5, 'Null values: 86')
plt.text(3, 3.5, 'Null values: 31')
plt.text(4, 3.5, 'Null values: 3')
plt.text(5, 3.5, 'Null values: 0')
plt.text(6, 3.5, 'Null values: 0')
plt.text(7, 3.5, 'Null values: 0')
# Out:
# Text(7, 3.5, 'Null values: 0')

# %%
def fill_missing_ratings(df, category, fill_value):
    filtered_df = df[(df['Installs_category'] == category) & df['Rating'].isnull()]
    df.loc[filtered_df.index, 'Rating'] = fill_value
    return df

# %%
df = fill_missing_ratings(df, 'Low', 4.170970)

# %%
df = fill_missing_ratings(df, 'Very low', 4.637037)
df = fill_missing_ratings(df, 'Moderate', 4.035417)
df = fill_missing_ratings(df, 'More than moderate', 4.093255)
df = fill_missing_ratings(df, 'High', 4.207525)

# %%
df = fill_missing_ratings(df, 'no', 0)

# %%
df['Installs_category'].loc[df['Rating'].isnull()].value_counts()
# Out:
# Installs_category
# no                    0
# Very low              0
# Low                   0
# Moderate              0
# More than moderate    0
# High                  0
# Very High             0
# Top Notch             0
# Name: count, dtype: int64

# %%
df['Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x='Installs_category', y= 'Reviews', data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %%
plt.figure(figsize=(16, 6))
sns.boxplot(x='Installs_category', y= np.log10(df['Reviews']), data=df)
# Out:
# <Axes: xlabel='Installs_category', ylabel='Reviews'>

# %%
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='Rating', y='Reviews', hue='Installs_category', data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
plt.figure(figsize=(16, 6)) 
sns.scatterplot(x='Reviews', y='Installs', data=df)
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %%
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x=np.log10(df['Reviews']), y=np.log10(df['Installs']), data=df)
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %%
plt.figure(figsize=(16, 6)) # make figure size
sns.lmplot(x='Reviews', y='Installs', data=df)

# %%
df['Category'].value_counts().head(10)
# Out:
# Category
# FAMILY             1939
# GAME               1121
# TOOLS               841
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     386
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %%
df.groupby('Category')['Installs'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME                  3.154402e+10
# COMMUNICATION         2.415228e+10
# SOCIAL                1.251387e+10
# PRODUCTIVITY          1.246309e+10
# TOOLS                 1.145227e+10
# FAMILY                1.004163e+10
# PHOTOGRAPHY           9.721248e+09
# TRAVEL_AND_LOCAL      6.361887e+09
# VIDEO_PLAYERS         6.222003e+09
# NEWS_AND_MAGAZINES    5.393218e+09
# Name: Installs, dtype: float64

# %%
df.groupby('Category')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Category
# GAME               1.415537e+09
# COMMUNICATION      6.012736e+08
# SOCIAL             5.335768e+08
# FAMILY             3.967717e+08
# TOOLS              2.731810e+08
# PHOTOGRAPHY        2.042974e+08
# VIDEO_PLAYERS      1.103802e+08
# PRODUCTIVITY       1.025545e+08
# SHOPPING           9.493116e+07
# PERSONALIZATION    7.519274e+07
# Name: Reviews, dtype: float64

# %%
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Category
# EVENTS                 4.394346
# EDUCATION              4.373794
# BOOKS_AND_REFERENCE    4.358435
# PERSONALIZATION        4.322099
# ART_AND_DESIGN         4.298885
# GAME                   4.281926
# HEALTH_AND_FITNESS     4.273890
# PARENTING              4.259759
# SHOPPING               4.253376
# SPORTS                 4.253041
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(10,5))
df['Category'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Categories by Number of Apps')
plt.xlabel('Category')
plt.ylabel('Number of Apps')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
df.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(15).plot(kind='barh')
plt.title('Average Rating by Category')
plt.xlabel('Average Rating')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(3,3))
df['Type'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Free vs Paid Apps')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
top_installed = df[['App', 'Installs']].drop_duplicates().sort_values('Installs', ascending=False).head(10)
print("\nTop 10 Most Installed Apps:\n", top_installed)
# Out:
# Top 10 Most Installed Apps:
#                                  App      Installs
# 2554                        Google+  1.000000e+09
# 865               Google Play Games  1.000000e+09
# 3117      Maps - Navigate & Explore  1.000000e+09
# 2808                  Google Photos  1.000000e+09
# 3234                         Google  1.000000e+09
# 391   Skype - free IM & video calls  1.000000e+09
# 152               Google Play Books  1.000000e+09
# 3127             Google Street View  1.000000e+09
# 340                           Gmail  1.000000e+09
# 2545                      Instagram  1.000000e+09

# %%
df_paid = df[df['Type'] == 'Paid'].copy()
df_paid['Estimated Revenue'] = df_paid['Price'] * df_paid['Installs']
top_revenue = df_paid[['App', 'Estimated Revenue']].drop_duplicates().sort_values('Estimated Revenue', ascending=False).head(10)
print("\nTop 10 Revenue Generating Paid Apps:\n", top_revenue)
# Out:
# Top 10 Revenue Generating Paid Apps:
#                                  App  Estimated Revenue
# 2241                      Minecraft         69900000.0
# 5351                      I am rich         39999000.0
# 5356              I Am Rich Premium         19999500.0
# 4034                  Hitman Sniper          9900000.0
# 7417  Grand Theft Auto: San Andreas          6990000.0
# 5578        Sleep as Android Unlock          5990000.0
# 2883            Facetune - For Free          5990000.0
# 8804            DraStic DS Emulator          4990000.0
# 4367       I'm Rich - Trump Edition          4000000.0
# 5354                 I am Rich Plus          3999900.0

# %%
plt.figure(figsize=(10,5))
df['Size_MB'].dropna().plot(kind='hist', bins=50)
plt.title('Distribution of App Sizes (MB)')
plt.xlabel('Size (MB)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
df['Genres'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Apps')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[['Rating', 'Reviews', 'Installs', 'Price', 'Size_MB']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
